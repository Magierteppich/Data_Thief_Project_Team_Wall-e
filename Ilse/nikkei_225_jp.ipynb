# %%
import pandas as pd

# %%
nikkei_25 = pd.read_csv("C:/Users/Admin/Documents/ironhack/ironhack-projects/Data_Thief_Project_Team_Wall-e/data/NIKKEI_225_JP.csv")

# %%
nikkei_25.head()
# Out:
#          date   value
# 0  1949-05-16  176.21
# 1  1949-05-17  174.80
# 2  1949-05-18  172.53
# 3  1949-05-19  171.34
# 4  1949-05-20  169.20

# %%
nikkei_25.columns = ["date", "value_nikkei_25_jp"]

# %%
nikkei_25.head()
# Out:
#          date  value_nikkei_25_jp
# 0  1949-05-16              176.21
# 1  1949-05-17              174.80
# 2  1949-05-18              172.53
# 3  1949-05-19              171.34
# 4  1949-05-20              169.20

# %%
nikkei_25["date"] = pd.to_datetime(nikkei_25["date"])

# %%
nikkei_25.dtypes
# Out:
# date                  datetime64[ns]
# value_nikkei_25_jp           float64
# dtype: object

# %%
nikkei_25 = (nikkei_25[nikkei_25["date"] >= "2019-01-01"]
             .reset_index()
             .drop(columns="index"))

# %%
#nikkei_25.drop(columns="index")
# Out:
#           date  value_nikkei_25_jp
# 0   2019-01-04            19561.96
# 1   2019-01-07            20038.97
# 2   2019-01-08            20204.04
# 3   2019-01-09            20427.06
# 4   2019-01-10            20163.80
# ..         ...                 ...
# 299 2020-04-01            18065.41
# 300 2020-04-02            17818.72
# 301 2020-04-03            17820.19
# 302 2020-04-06            18576.30
# 303 2020-04-07            18950.18
#
# [304 rows x 2 columns]

# %%
nikkei_25.head()
# Out:
#         date  value_nikkei_25_jp
# 0 2019-01-04            19561.96
# 1 2019-01-07            20038.97
# 2 2019-01-08            20204.04
# 3 2019-01-09            20427.06
# 4 2019-01-10            20163.80

# %%
nikkei_25.dtypes
# Out:
# date                  datetime64[ns]
# value_nikkei_25_jp           float64
# dtype: object

# %%
nikkei_25 = nikkei_25.sort_values("date", ascending=False)

# %%
nikkei_25 = nikkei_25.reset_index().drop(columns="index")

# %%
nikkei_25.head()
# Out:
#         date  value_nikkei_25_jp
# 0 2020-04-07            18950.18
# 1 2020-04-06            18576.30
# 2 2020-04-03            17820.19
# 3 2020-04-02            17818.72
# 4 2020-04-01            18065.41

# %%
nikkei_25.to_csv("C:/Users/Admin/Documents/ironhack/ironhack-projects/Data_Thief_Project_Team_Wall-e/data/NIKKEI_225_JP_clean.csv", index=False)

# %%
import requests
import bs4

# %%
url = "https://finance.yahoo.com/quote/%5EGDAXI/history/"
resp = requests.get(url)

# %%
resp.content
# Out:
# b'<!DOCTYPE html><html id="atomic" class="NoJs featurephone" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><title>DAX PERFORMANCE-INDEX (^GDAXI) Historical Data - Yahoo Finance</title><meta name="keywords" content="^GDAXI, DAX PERFORMANCE-INDEX, ^GDAXI historical prices, DAX PERFORMANCE-INDEX historical prices, historical prices, stocks, quotes, finance"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="90376669494"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="Get historical data for the DAX PERFORMANCE-INDEX (^GDAXI) on Yahoo Finance. View and download daily, weekly or monthly data to help your investment decisions."/><meta name="oath:guce:consent-host" c
# ...

# %%
soup = bs4.BeautifulSoup(resp.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find("div", class_="D(ib) Va(m) Maw(65%) Ov(h)")[0]

#<div class="D(ib) Va(m) Maw(65%) Ov(h)" data-reactid="30"><div class="D(ib) Mend(20px)" data-reactid="31"><span class="Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)" data-reactid="32">10,264.24</span><span class="Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($dataRed)" data-reactid="33">-92.46 (-0.89%)</span><div id="quote-market-notice" class="C($tertiaryColor) D(b) Fz(12px) Fw(n) Mstart(0)--mobpsm Mt(6px)--mobpsm" data-reactid="34"><span data-reactid="35">As of  12:32PM CEST. Market open.</span></div></div></div>
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-8ac3be6450bb> in <module>
# ----> 1 soup.find("div", class_="D(ib) Va(m) Maw(65%) Ov(h)")[0]
#       2
#       3 #<div class="D(ib) Va(m) Maw(65%) Ov(h)" data-reactid="30"><div class="D(ib) Mend(20px)" data-reactid="31"><span class="Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)" data-reactid="32">10,264.24</span><span class="Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($dataRed)" data-reactid="33">-92.46 (-0.89%)</span><div id="quote-market-notice" class="C($tertiaryColor) D(b) Fz(12px) Fw(n) Mstart(0)--mobpsm Mt(6px)--mobpsm" data-reactid="34"><span data-reactid="35">As of  12:32PM CEST. Market open.</span></div></div></div>
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-a3579600a33a> in <module>
# ----> 1 soup.find("div", id= "YDC_Lead", class_="YDC-Lead")[0]
#
# TypeError: 'NoneType' object is not subscriptable
