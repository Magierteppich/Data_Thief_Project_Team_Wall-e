# %%
import pandas as pd
import requests
import json
from pandas.io.json import json_normalize

# %%
url = "http://api.aviationstack.com/v1/airports?access_key=eaa849f47f0c13f682ddd466380d9f60"

resp = requests.get(url)

# %%
pd.DataFrame(resp.json()["data"])
# Out:
#     gmt iata_code city_iata_code icao_code country_iso2 geoname_id   latitude  \
# 0   -10       AAA            AAA      NTGA           PF    6947726     -17.05
# 1    10       AAB            AAB      YARY           AU    7730796      -26.7
# 2     2       AAC            AAC      HEAR           EG    6297289  31.133333
# 3     1       AAE            AAE      DABB           DZ    2570559  36.821392
# 4    -5       AAF            AAF      KAAF           US    4146153  29.733334
# ..  ...       ...            ...       ...          ...        ...        ...
# 95   -7       AFO            AFO      KAFO           US    5816866  42.733334
# 96    5       AFS            AFS      UTSN           UZ    7730807   41.61361
# 97   11       AFT            AFT      AGAF           SB    8298931       -9.2
# 98   -6       AFW            DFW      KAFW           US    4691932  32.986668
# 99    3       AFY            AFY      LTAH           TR    6299728  38.733334
#
# ...
